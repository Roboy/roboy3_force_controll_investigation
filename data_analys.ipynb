# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp
from scipy.optimize import curve_fit
from scipy.misc import derivative

# %%
#import data
s100G1 = pd.read_csv(r'motorDataLengthMappingSmall-100-1637675318.csv')

s300G1 = pd.read_csv(r'motorDataLengthMappingSmall-300-1637675153.csv')

s500G1 = pd.read_csv(r'motorDataLengthMappingSmall-500-1637674928.csv')

s700G1 = pd.read_csv(r'motorDataLengthMappingSmall-700-1637674715.csv')

s800G1 = pd.read_csv(r'motorDataLengthMappingSmall-800-1637674380.csv')

s2500G1 = pd.read_csv(r'motorDataLengthMappingSmall-2500g-1637178332.csv')
s2500G2 = pd.read_csv(r'motorDataLengthMappingSmall-2500-1637674141.csv')

#s5000G1 = pd.read_csv(r'motorDataLengthMappingSmall-1637175804.csv')
#s5000G2 = pd.read_csv(r'motorDataLengthMappingSmall-1637175804.csv')

s7500G1 = pd.read_csv(r'motorDataLengthMappingSmall-7500-1637673187.csv')
s7500G2 = pd.read_csv(r'motorDataLengthMappingSmall-7500-1637673357.csv')

s10000G1 = pd.read_csv(r'motorDataLengthMappingSmall-10000-1637673620.csv')
s10000G2 = pd.read_csv(r'motorDataLengthMappingSmall-10000-1637673847.csv')

# %%
#define function
def objective(x, a, b):
	return a * x + b

def f(x):
    return a * x + b

# %%
#calculate values for the fitted function
#also the derivative (it was a try do not think about them)
out_x = np.arange(0,20,1)

#s100G1
raw_x = np.arange(0,19,1)
popt, _ = curve_fit(objective, raw_x, s100G1['displacements'])
a, b = popt
d100G1 = np.zeros(len(out_x))
f100G1 = np.zeros(len(out_x))
for idx, val in enumerate(out_x):
    f100G1[idx] = f(val) 
    d100G1[idx] = derivative(f,val)

#s300G1
raw_x = np.arange(0,21,1)
popt, _ = curve_fit(objective, raw_x, s300G1['displacements'])
a, b = popt
d300G1 = np.zeros(len(out_x))
f300G1 = np.zeros(len(out_x))
for idx, val in enumerate(out_x):
    f300G1[idx] = f(val) 
    d300G1[idx] = derivative(f,val)

#s500G1
raw_x = np.arange(0,20,1)
popt, _ = curve_fit(objective, raw_x, s500G1['displacements'])
a, b = popt
d500G1 = np.zeros(len(out_x))
f500G1 = np.zeros(len(out_x))
for idx, val in enumerate(out_x):
    f500G1[idx] = f(val) 
    d500G1[idx] = derivative(f,val)
    
#s700G1
popt, _ = curve_fit(objective, raw_x, s700G1['displacements'])
a, b = popt
d700G1 = np.zeros(len(out_x))
f700G1 = np.zeros(len(out_x))
for idx, val in enumerate(out_x):
    f700G1[idx] = f(val) 
    d700G1[idx] = derivative(f,val)
    
#s800G1
popt, _ = curve_fit(objective, raw_x, s800G1['displacements'])
a, b = popt
d800G1 = np.zeros(len(out_x))
f800G1 = np.zeros(len(out_x))
for idx, val in enumerate(out_x):
    f800G1[idx] = f(val) 
    d800G1[idx] = derivative(f,val)
    
#s2500G1
popt, _ = curve_fit(objective, raw_x, s2500G1['displacements'])
a, b = popt
d2500G1 = np.zeros(len(out_x))
f2500G1 = np.zeros(len(out_x))
for idx, val in enumerate(out_x):
    f2500G1[idx] = f(val) 
    d2500G1[idx] = derivative(f,val)

#s2500G2
raw_x = np.arange(0,21,1)
popt, _ = curve_fit(objective, raw_x, s2500G2['displacements'])
a, b = popt
d2500G2 = np.zeros(len(out_x))
f2500G2 = np.zeros(len(out_x))
for idx, val in enumerate(out_x):
    f2500G2[idx] = f(val) 
    d2500G2[idx] = derivative(f,val)

#s7500G1
raw_x = np.arange(0,20,1)
popt, _ = curve_fit(objective, raw_x, s7500G1['displacements'])
a, b = popt
d7500G1 = np.zeros(len(out_x))
f7500G1 = np.zeros(len(out_x))
for idx, val in enumerate(out_x):
    f7500G1[idx] = f(val) 
    d7500G1[idx] = derivative(f,val)
    
#s7500G2
popt, _ = curve_fit(objective, raw_x, s7500G2['displacements'])
a, b = popt
d7500G2 = np.zeros(len(out_x))
f7500G2 = np.zeros(len(out_x))
for idx, val in enumerate(out_x):
    f7500G2[idx] = f(val) 
    d7500G2[idx] = derivative(f,val)
    
#s10000G1
raw_x = np.arange(0,21,1)
popt, _ = curve_fit(objective, raw_x, s10000G1['displacements'])
a, b = popt
d10000G1 = np.zeros(len(out_x))
f10000G1 = np.zeros(len(out_x))
for idx, val in enumerate(out_x):
    f10000G1[idx] = f(val) 
    d10000G1[idx] = derivative(f,val)
    
#s10000G2
raw_x = np.arange(0,20,1)
popt, _ = curve_fit(objective, raw_x, s10000G2['displacements'])
a, b = popt
d10000G2 = np.zeros(len(out_x))
f10000G2 = np.zeros(len(out_x))
for idx, val in enumerate(out_x):
    f10000G2[idx] = f(val) 
    d10000G2[idx] = derivative(f,val)

# %%
#plot raw displacement
#the name in the legend is the variable name from which the values are comming from and the number in front of the G
#is for the mass of the attached weight
plt.figure(figsize=(20,10))
plt.plot(s100G1['displacements'], label = "s100G1")

plt.plot(s300G1['displacements'], label = "s300G1")

plt.plot(s500G1['displacements'], label = "s500G1")

plt.plot(s700G1['displacements'], label = "s700G1")

plt.plot(s800G1['displacements'], label = "s800G1")

plt.plot(s2500G1['displacements'], label = "s2500G1")
plt.plot(s2500G2['displacements'], label = "s2500G2")

plt.plot(s7500G1['displacements'], label = "s7500G1")
plt.plot(s7500G2['displacements'], label = "s7500G2")

plt.plot(s10000G1['displacements'], label = "s10000G1")
plt.plot(s10000G2['displacements'], label = "s10000G2")

plt.xlabel("cm in real world / plotting indices")
plt.ylabel("displacment value")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#plot fitted function
plt.figure(figsize=(20,10))
plt.plot(f100G1, label = "f100G1")

plt.plot(f300G1, label = "f300G1")

plt.plot(f500G1, label = "f500G1")

plt.plot(f700G1, label = "f700G1")

plt.plot(f800G1, label = "f800G1")

plt.plot(f2500G1, label = "f2500G1")
plt.plot(f2500G2, label = "f2500G2")

plt.plot(f7500G1, label = "f7500G1")
plt.plot(f7500G2, label = "f7500G2")

plt.plot(f10000G1, label = "f10000G1")
plt.plot(f10000G2, label = "f10000G2")

plt.xlabel("cm in real world / plotting indices")
plt.ylabel("displacment value")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
